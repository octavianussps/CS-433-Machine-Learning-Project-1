# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
from proj1_helpers import *

# %%
y, tX, idx = load_csv_data("../data/train.csv")
#data_train = pd.read_csv("../data/train.csv.zip")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-de45080bd096> in <module>
# ----> 1 y, tX, idx = load_csv_data("../data/train.csv.zip")
#       2 #data_train = pd.read_csv("../data/train.csv.zip")
#
# ~/ML-Project-1-CS-433-/scripts/proj1_helpers.py in load_csv_data(data_path, sub_sample)
#       7 def load_csv_data(data_path, sub_sample=False):
#       8     """Loads data and returns y (class labels), tX (features) and ids (event ids)"""
# ----> 9     y = np.genfromtxt(data_path, delimiter=",", skip_header=1, dtype=str, usecols=1)
#      10     x = np.genfromtxt(data_path, delimiter=",", skip_header=1)
#      11     ids = x[:, 0].astype(np.int)
#
# ...

# %%
data_train
# Out:
#             Id Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# 0       100000          s       138.470                       51.655
# 1       100001          b       160.937                       68.768
# 2       100002          b      -999.000                      162.172
# 3       100003          b       143.905                       81.417
# 4       100004          b       175.864                       16.915
# ...        ...        ...           ...                          ...
# 249995  349995          b      -999.000                       71.989
# 249996  349996          b      -999.000                       58.179
# 249997  349997          s       105.457                       60.526
# 249998  349998          b        94.951                       19.362
# 249999  349999          b      -999.000                       72.756
#
#         DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# ...
