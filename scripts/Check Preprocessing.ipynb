# %%
from preprocessing import *
from helpers import *
from implementations import *
from proj1_helpers import *
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import the data (Class, Features, Ids)

# %%
print("LOAD DATA")
ys_train, x_train, ids_train = load_csv_data("../data/train.csv")
y_test, x_test, ids_test = load_csv_data("../data/test.csv")
# Out:
# LOAD DATA

# %% [markdown]
# Check the Features

# %%
print("FILTERING DATA")
print("check standardize")
x_test, x_train = standardize(x_test, x_train)
# Out:
# FILTERING DATA
# check standardize
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f44c0332240>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f44c1c0b390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f44c0332e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f44c1c0ba20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f44c1c0bd68>],
#  'means': []}

# %%
# for i column only
#for i in range(30):
#    plt.boxplot(x_train[:,i])
# for all data
plt.boxplot(x_train)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f4474ba5e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f4474ba6550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f4474ba5a90>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f4474ba6be0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f4474ba6f28>,
# ...
#  'means': []}

# %%
# for i column only
#for i in range(30):
#    plt.boxplot(x_test[:,i])
# for all data
plt.boxplot(x_test)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f4474bb0668>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f4474bb0c18>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f4474bb0390>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f446dfef438>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f446dfef710>,
# ...
#  'means': []}

# %%
print("check removal")
x_train, ys_train = remove_outliers(x_train, ys_train)
# Out:
# check removal

# %%
# for i column only
#for i in range(30):
#    plt.boxplot(x_train[:,i])
# for all data
plt.boxplot(x_train)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f446c4a0320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f446c4a09b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f446c4a3ef0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f446c4a0dd8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f446c4c33c8>,
# ...
#  'means': []}

# %%
# for i column only
#for i in range(30):
#    plt.boxplot(x_train[:,i])
# for all data
plt.boxplot(x_test)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f44bda43748>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f44bda43dd8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f44bda43358>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f44c1ba94a8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f44c1ba97f0>,
# ...
#  'means': []}

# %%
plt.boxplot(x_test[:,3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f44c1041860>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f44c1041ef0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f44c1041470>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f44c10455c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f44c1045908>],
#  'means': []}

# %% [markdown]
# Check Null Values

# %%
np.argwhere(np.isnan(x_train))
#result none
# Out:
# array([], shape=(0, 2), dtype=int64)

# %%
np.argwhere(np.isnan(x_test))
#result none
# Out:
# array([], shape=(0, 2), dtype=int64)

# %%
np.argwhere(np.isinf(x_train))
#result none
# Out:
# array([], shape=(0, 2), dtype=int64)

# %%
np.argwhere(np.isinf(x_test))
#result none
# Out:
# array([], shape=(0, 2), dtype=int64)
